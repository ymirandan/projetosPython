# %% [markdown]
# <a href="https://colab.research.google.com/github/ymirandan/projetosPython/blob/main/An%C3%A1lise%20Explorat%C3%B3ria/Revis%C3%A3o/Curso%20IA%20e%20ML%3A%20Revisao%20-%20Exercicio2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Olá!
#
# Para revisar o conteúdo prático visto até agora, você agora pode resolver dois exercícios. Logo em seguida você pode acessar a aula em vídeo com a solução
#
# Leia a idade do usuário e classifique-o em:
# - Criança – 0 a 12 anos
# - Adolescente – 13 a 17 anos
# - Adulto – acima de 18 anos
# -Se o usuário digitar um número negativo, mostrar a mensagem que a idade é inválida
#
#
#
# Calcular a média de um aluno que cursou a disciplina de Programação I, a partir da leitura das notas M1, M2 e M3; passando por um cálculo da média aritmética. Após a média calculada, devemos anunciar se o aluno foi aprovado, reprovado ou pegou exame
# - Se a média estiver entre 0.0 e 4.0, o aluno está reprovado
# - Se a média estiver entre 4.1 e 6.0, o aluno pegou exame
# - Se a média for maior do que 6.0, o aluno está aprovado
# - Se o aluno pegou exame, deve ser lida a nota do exame. Se a nota do exame for maior do que 6.0, está aprovado, senão; está reprovado
#
# Bom trabalho,
#
# Jones

# %%
idade = int(input("Digite a sua idade (anos): "))

while idade <0:
  print("Idade inválida, digite um número maior ou igual a 0")
  idade = int(input("Digite a sua idade (anos): "))
if idade < 13: print("Você é criança")
elif idade < 18: print("Você é adolescente")
else: print("Você é adulto")
# Out:
# Digite a sua idade (anos): -2
# Idade inválida, digite um número maior ou igual a 0
# Digite a sua idade (anos): -36
# Idade inválida, digite um número maior ou igual a 0
# Digite a sua idade (anos): 49
# Você é adulto

# %%
def media_final(tem_peso, nota1,nota2,nota3):
  if tem_peso == "sim":
    media_simples = (nota1+nota2+nota3)/3
    print(f"Sua média final é: {round(media_simples,2)}")
    if media_simples < 4: situacao = "reprovou"
    elif media_simples <6:
      situacao = "fez recuperação"
      exame = float(input("Digite sua nota da recuperação: "))
      if exame > 6:
        situacao = "está aprovado"
      else: situacao = "reprovou"
    else: situacao = "está aprovado"
    print(f"Você {situacao}")
  else:
    peso_nota1 = float(input("Digite o peso da nota M1: "))
    peso_nota2 = float(input("Digite o peso da nota M2: "))
    peso_nota3 = float(input("Digite o peso da nota M3: "))
    media_ponderada = ((nota1*peso_nota1) + (nota2*peso_nota2) + (nota3*peso_nota3)) / (peso_nota1+peso_nota2+peso_nota3)
    print(f"Sua média final é: {round(media_ponderada,2)}")
    if media_ponderada < 4: situacao = "reprovou"
    elif media_ponderada <6:
      situacao = "fez recuperação"
      exame = float(input("Digite sua nota da recuperação: "))
      if exame > 6:
        situacao = "está aprovado"
      else: situacao = "reprovou"
    else: situacao = "está aprovado"
    print(f"Você {situacao}")

# %%
nota1 = float(input("Digite a sua nota da M1: "))
nota2 = float(input("Digite a sua nota da M2: "))
nota3 = float(input("Digite a sua nota da M3: "))
# Out:
# Digite a sua nota da M1: 6
# Digite a sua nota da M2: 2
# Digite a sua nota da M3: 8

# %%
tem_peso = str(input("Todas as notas têm o mesmo peso? (Digite sim ou não) "))
# Out:
# Todas as notas têm o mesmo peso? (Digite sim ou não) não

# %%
media_final(tem_peso, nota1, nota2,nota3)
# Out:
# Digite o peso da nota M1: 2
# Digite o peso da nota M2: 1
# Digite o peso da nota M3: 1
# Sua média final é: 5.5
# Digite sua nota da recuperação: 5.9
# Você reprovou
